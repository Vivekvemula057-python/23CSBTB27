# %% [markdown]
# <a href="https://colab.research.google.com/github/Vivekvemula057-python/23CSBTB27/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![BFS.jpg](data:image/jpeg;base64,...)

# %%
from queue import Queue
graph = {0: [1, 2, 3],
1: [0, 2],
2: [1, 3, 5],
3: [0, 2, 4],
4: [3, 5, 7],
5: [2, 4, 6, 7],
6: [5, 7],
7:[]}
print("The adjacency List representing the graph is:")
print(graph)
# Out:
# The adjacency List representing the graph is:
# {0: [1, 2, 3], 1: [0, 2], 2: [1, 3, 5], 3: [0, 2, 4], 4: [3, 5, 7], 5: [2, 4, 6, 7], 6: [5, 7], 7: []}

# %% [markdown]
# ![DFS.jpg](data:image/jpeg;base64,...)

# %%
graph1 = {
'A' : ['B','C','G'],
'B' : ['A'],
'C' : ['A','D','F',],
'D' : ['A','C','E','H'],
'E' : ['D','H','F'],
'F' : ['C','E'],
'G' : ['A','D','H'],
'H' : ['D','E','G']
}
def dfs(graph, node, visited):
  if node not in visited:
    visited.append(node)
    for k in graph[node]:
      dfs(graph,k, visited)
      return visited
      visited = dfs(graph1,'B', [])
      print(visited)
